# %%
import sys
import os 
import pandas as pd 
import numpy as np
import re
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MultiLabelBinarizer
import unicodedata
import json

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.text_cleaner import clean_text, title_to_index

# %%
movie_data = pd.read_csv("../data/movie_metadata.csv")

# %%
movie_data.head(20)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# ...

# %%
movie_data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie_data.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
data = movie_data[['movie_title', 'genres', 'plot_keywords', 'num_critic_for_reviews', 'imdb_score','duration', 'num_user_for_reviews']]

# %%
data.head()
# Out:
#                                          movie_title  \
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
#
#                             genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
#                                        plot_keywords  num_critic_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                   723.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                   302.0
# 2                bomb|espionage|sequel|spy|terrorist                   602.0
# 3  deception|imprisonment|lawlessness|police offi...                   813.0
# ...

# %%
data.isna().sum()
# Out:
# movie_title                 0
# genres                      0
# plot_keywords             153
# num_critic_for_reviews     50
# imdb_score                  0
# duration                   15
# num_user_for_reviews       21
# dtype: int64

# %%
data = data.dropna(axis=0, subset=["plot_keywords"])

# %%
data.num_critic_for_reviews.fillna(data.num_critic_for_reviews.median(), inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_27496\2462707496.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.num_critic_for_reviews.fillna(data.num_critic_for_reviews.median(), inplace=True)

# %%
print(data.num_user_for_reviews.median())
print(data.num_user_for_reviews.max())
print(data.num_user_for_reviews.min())
print(data.num_user_for_reviews.mean())
# Out:
# 162.0
# 5060.0
# 1.0
# 280.2215850911325

# %%
data.isna().sum()
# Out:
# movie_title               0
# genres                    0
# plot_keywords             0
# num_critic_for_reviews    0
# imdb_score                0
# duration                  8
# num_user_for_reviews      7
# dtype: int64

# %%
data.num_user_for_reviews.fillna(data.num_user_for_reviews.median(), inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_27496\2776267504.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.num_user_for_reviews.fillna(data.num_user_for_reviews.median(), inplace=True)

# %%
data.isna().sum()
# Out:
# movie_title               0
# genres                    0
# plot_keywords             0
# num_critic_for_reviews    0
# imdb_score                0
# duration                  8
# num_user_for_reviews      0
# dtype: int64

# %%
data["clean_plot_keywords"] = data["plot_keywords"].apply(clean_text)
data['clean_genres'] = data['genres'].apply(clean_text)

# %%
data.head()
# Out:
#                                  movie_title                           genres  \
# 0                                    Avatar   Action|Adventure|Fantasy|Sci-Fi
# 1  Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# 2                                   Spectre         Action|Adventure|Thriller
# 3                     The Dark Knight Rises                   Action|Thriller
# 5                               John Carter           Action|Adventure|Sci-Fi
#
#                                        plot_keywords  num_critic_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                   723.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                   302.0
# 2                bomb|espionage|sequel|spy|terrorist                   602.0
# 3  deception|imprisonment|lawlessness|police offi...                   813.0
# 5  alien|american civil war|male nipple|mars|prin...                   462.0
#
# ...

# %%
data['merged_text_columns'] = ( 
    data['clean_plot_keywords'] + ' ' + data['clean_genres']
)

# %%
data = data.drop(columns=['clean_genres', 'clean_plot_keywords'])

# %%
scaler = MinMaxScaler()

# %%
data['imdb_score'].fillna(data['imdb_score'].mean(), inplace=True)
data['duration'].fillna(data['duration'].mean(), inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_27496\2083979292.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['imdb_score'].fillna(data['imdb_score'].mean(), inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_27496\2083979292.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data[['imdb_score', 'duration']].isna().sum()
# Out:
# imdb_score    0
# duration      0
# dtype: int64

# %%
data[['imdb_score', 'duration']].head
# Out:
# <bound method NDFrame.head of       imdb_score  duration
# 0            7.9     178.0
# 1            7.1     169.0
# 2            6.8     148.0
# 3            8.5     164.0
# 5            6.6     132.0
# ...          ...       ...
# 5036         7.8      84.0
# 5037         6.4      95.0
# 5038         7.7      87.0
# 5039         7.5      43.0
# 5042         6.6      90.0
#
# [4890 rows x 2 columns]>

# %%
data[['imdb_score_norm', 'duration_norm']] = scaler.fit_transform(data[['imdb_score', 'duration']])

# %%
mlb = MultiLabelBinarizer()

# %%
data['genres'] = data['genres'].fillna('').astype(str).apply (lambda x: x.split('|'))

genre_encoded = mlb.fit_transform(data['genres'])

genre_df = pd.DataFrame(genre_encoded, columns=mlb.classes_, index=data.index)

data= pd.concat([data, genre_df], axis=1)

data.head
# Out:
# <bound method NDFrame.head of                                     movie_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# ...                                         ...
# 5036                           The Mongol King
# 5037                                 Newlyweds
# 5038                   Signed Sealed Delivered
# 5039                 The Following
# 5042                         My Date with Drew
#
#                                     genres  \
# 0     [Action, Adventure, Fantasy, Sci-Fi]
# 1             [Action, Adventure, Fantasy]
# 2            [Action, Adventure, Thriller]
# 3                       [Action, Thriller]
# 5              [Action, Adventure, Sci-Fi]
# ...                                    ...
# 5036                        [Crime, Drama]
# ...

# %%
print(mlb.classes_)
# Out:
# ['Action' 'Adventure' 'Animation' 'Biography' 'Comedy' 'Crime'
#  'Documentary' 'Drama' 'Family' 'Fantasy' 'Film-Noir' 'Game-Show'
#  'History' 'Horror' 'Music' 'Musical' 'Mystery' 'News' 'Reality-TV'
#  'Romance' 'Sci-Fi' 'Short' 'Sport' 'Thriller' 'War' 'Western']

# %%
data.columns
# Out:
# Index(['movie_title', 'genres', 'plot_keywords', 'num_critic_for_reviews',
#        'imdb_score', 'duration', 'num_user_for_reviews', 'merged_text_columns',
#        'imdb_score_norm', 'duration_norm', 'Action', 'Adventure', 'Animation',
#        'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#        'Fantasy', 'Film-Noir', 'Game-Show', 'History', 'Horror', 'Music',
#        'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi',
#        'Short', 'Sport', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
numeric_data = data[['imdb_score_norm', 'duration_norm']]

# %%
numeric_data.head()
# Out:
#    imdb_score_norm  duration_norm
# 0         0.818182       0.339286
# 1         0.714286       0.321429
# 2         0.675325       0.279762
# 3         0.896104       0.311508
# 5         0.649351       0.248016

# %%
data.head()
# Out:
#                                  movie_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 5                               John Carter
#
#                                  genres  \
# 0  [Action, Adventure, Fantasy, Sci-Fi]
# 1          [Action, Adventure, Fantasy]
# 2         [Action, Adventure, Thriller]
# 3                    [Action, Thriller]
# 5           [Action, Adventure, Sci-Fi]
#
#                                        plot_keywords  num_critic_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                   723.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                   302.0
# 2                bomb|espionage|sequel|spy|terrorist                   602.0
# 3  deception|imprisonment|lawlessness|police offi...                   813.0
# ...

# %%
data = data.drop(columns=['plot_keywords', 'num_critic_for_reviews', 'num_user_for_reviews',])

# %%
data.columns
# Out:
# Index(['movie_title', 'genres', 'imdb_score', 'duration',
#        'merged_text_columns', 'imdb_score_norm', 'duration_norm', 'Action',
#        'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary',
#        'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show', 'History',
#        'Horror', 'Music', 'Musical', 'Mystery', 'News', 'Reality-TV',
#        'Romance', 'Sci-Fi', 'Short', 'Sport', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
print(data['movie_title'].head(10))
# Out:
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# 6                                 Spider-Man 3
# 7                                      Tangled
# 8                      Avengers: Age of Ultron
# 9       Harry Potter and the Half-Blood Prince
# 10          Batman v Superman: Dawn of Justice
# Name: movie_title, dtype: object

# %%
indexed_title = title_to_index(data['movie_title'])

print(indexed_title)
# Out:
# {'Avatar\xa0': 0, "Pirates of the Caribbean: At World's End\xa0": 1, 'Spectre\xa0': 2, 'The Dark Knight Rises\xa0': 3, 'John Carter\xa0': 4, 'Spider-Man 3\xa0': 3417, 'Tangled\xa0': 6, 'Avengers: Age of Ultron\xa0': 7, 'Harry Potter and the Half-Blood Prince\xa0': 8, 'Batman v Superman: Dawn of Justice\xa0': 9, 'Superman Returns\xa0': 10, 'Quantum of Solace\xa0': 11, "Pirates of the Caribbean: Dead Man's Chest\xa0": 12, 'The Lone Ranger\xa0': 13, 'Man of Steel\xa0': 14, 'The Chronicles of Narnia: Prince Caspian\xa0': 15, 'The Avengers\xa0': 788, 'Pirates of the Caribbean: On Stranger Tides\xa0': 17, 'Men in Black 3\xa0': 18, 'The Hobbit: The Battle of the Five Armies\xa0': 19, 'The Amazing Spider-Man\xa0': 20, 'Robin Hood\xa0': 21, 'The Hobbit: The Desolation of Smaug\xa0': 22, 'The Golden Compass\xa0': 23, 'King Kong\xa0': 4591, 'Titanic\xa0': 25, 'Captain America: Civil War\xa0': 26, 'Battleship\xa0': 27, 'Jurassic World\xa0': 28, 'Skyfall\xa0': 3449, 'Spider-Man 2\xa0': 30, 'Iron 
# ...

# %%
cleaned_indexed_title = {
    unicodedata.normalize("NFKD", title): index
    for title, index in indexed_title.items()
}

# %%
print(cleaned_indexed_title)
# Out:
# {'Avatar ': 0, "Pirates of the Caribbean: At World's End ": 1, 'Spectre ': 2, 'The Dark Knight Rises ': 3, 'John Carter ': 4, 'Spider-Man 3 ': 3417, 'Tangled ': 6, 'Avengers: Age of Ultron ': 7, 'Harry Potter and the Half-Blood Prince ': 8, 'Batman v Superman: Dawn of Justice ': 9, 'Superman Returns ': 10, 'Quantum of Solace ': 11, "Pirates of the Caribbean: Dead Man's Chest ": 12, 'The Lone Ranger ': 13, 'Man of Steel ': 14, 'The Chronicles of Narnia: Prince Caspian ': 15, 'The Avengers ': 788, 'Pirates of the Caribbean: On Stranger Tides ': 17, 'Men in Black 3 ': 18, 'The Hobbit: The Battle of the Five Armies ': 19, 'The Amazing Spider-Man ': 20, 'Robin Hood ': 21, 'The Hobbit: The Desolation of Smaug ': 22, 'The Golden Compass ': 23, 'King Kong ': 4591, 'Titanic ': 25, 'Captain America: Civil War ': 26, 'Battleship ': 27, 'Jurassic World ': 28, 'Skyfall ': 3449, 'Spider-Man 2 ': 30, 'Iron Man 3 ': 31, 'Alice in Wonderland ': 4064, 'X-Men: The Last Stand ': 33, 'Monsters University
# ...

# %%
os.makedirs("../data", exist_ok=True)

with open("../data/title_to_index.json", "w", encoding="utf-8") as f:
    json.dump(cleaned_indexed_title, f, indent=4, ensure_ascii=False)

# %%
data.to_csv("../data/cleaned_data.csv", index=False)
genre_df.to_csv("../data/genre_df.csv", index=False)
numeric_data.to_csv("../data/numeric_data.csv", index=False)
